# %% [markdown]
# # Supervisor Subagent Notebook
#
# This notebook is for me to practise orchestrating subagents and a supervisor for my use case. My wife always struggles to find food places and activities that is the midpoint between her and her friends.
#
# Subagents:
#
# 1. midpoint_locator finds the midpoint area that is accessible
# 2. food_agent finds the most suitable restuarants available
# 3. activity_agent finds the most suitable acitivities available

# %%
# Friends meetup planner 

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Agent Function/Client Setup

# %%
# agent 1 to find postcode into lat/lon then compute midpoint and then area of Lond

import requests
from typing import Tuple, Dict

def postcode_to_latlon(postcode: str) -> Tuple[float, float]:
    """
    Convert a UK postcode into latitude and longitude.

    Args:
        postcode: UK postcode (e.g. "SW1A 1AA")

    Returns:
        A tuple of (latitude, longitude).
    """
    url = f"https://api.postcodes.io/postcodes/{postcode}"
    r = requests.get(url).json()["result"]
    return r["latitude"], r["longitude"]


def midpoint_latlon(
    lat1: float, long1: float, lat2: float, long2: float
) -> Tuple[float, float]:
    """
    Compute the midpoint between two latitude/longitude pairs.

    Args:
        lat1: Latitude of first location.
        long1: Longitude of first location.
        lat2: Latitude of second location.
        long2: Longitude of second location.

    Returns:
        A tuple of (mid_latitude, mid_longitude).
    """
    mid_lat = (lat1 + lat2) / 2
    mid_long = (long1 + long2) / 2
    return mid_lat, mid_long

def latlong_to_area(lat: float, long: float):
    url = f"https://api.postcodes.io/postcodes?lon={long}&lat={lat}&radius=2000&limit=1"
    data = requests.get(url).json()

    if data.get("status") != 200 or not data.get("result"):
        raise ValueError(f"Reverse lookup failed: {data}")

    r = data["result"][0]
    return {
        "postcode": r["postcode"],
        "district": r["admin_district"],
        "region": r["region"],
    }

# %%
# agent 2 and 3 will search the web using Tavily Client
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %% [markdown]
# ## State schema created
#
# State schema created to enable the agent to reply back in a specific format for my wife to share via whatsapp to her friends to pick!

# %%
from langchain.agents import AgentState

# creating a meetup event state to track
class MeetUpState(AgentState):
    person_1_postcode: str
    person_2_postcode: str
    midpoint_area: str
    food_place: str
    activity_place: str

# %% [markdown]
# ## Subagents with system prompt

# %%
from langchain.agents import create_agent

# create subagents

midpoint_agent = create_agent(
    model='gpt-5-nano',
    tools=[],
    system_prompt = """
    You are a location agent. 
    You must take the postcode of person 1 and person 2, compute the midpoint between the two, then take the midpoint latlong and get the area it's associated with.
    You will be given no extra information, only the two postcodes in London. 
    Once you have found the area, it will be used for the other agents.
    """ 
)

food_agent = create_agent(
    model='gpt-5-nano',
    tools=[web_search],
    system_prompt = """
       You are a food specialist. Search for food spots in the desired location and give the best 3 options for the user to decide.
    You are not allowed to ask any more follow up questions, you must find the suitable food options based on the following criteria:
    - Halal meats
    - Has google reviews of over 4.3 stars in average
    - Cuisine: Indian, chinese, american, burgers, vegan, vegetarian
    - Is there a space to pray for Muslims?
    You may need to make multiple searches to iteratively find the best options.
        """
)

activity_agent = create_agent(
    model='gpt-5-nano',
    tools=[web_search],
    system_prompt="""
    You are a activity specialist. Search the web for activities to do within the desired location and give the best 3 options for the user to decide.
    You are not allowed to ask any more follow up questions, you must find the suitable food options based on the following criteria:
    - Must be beginner friendly
    - Must be reasonably priced
    - Must have good reviews
    You may need to make multiple queries to iteratively find the best options.
    """
)

# %% [markdown]
# ## Main Co-ordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def find_area(person_1_postcode: str, person_2_postcode: str, runtime: ToolRuntime) -> Command:
    """Finds the area from given postcodes"""
    p1 = person_1_postcode.replace(" ", "").upper()
    p2 = person_2_postcode.replace(" ", "").upper()

    # call your existing python functions (postcodes.io)
    lat1, lon1 = postcode_to_latlon(p1)
    lat2, lon2 = postcode_to_latlon(p2)
    mid_lat, mid_lon = midpoint_latlon(lat1, lon1, lat2, lon2)
    area = latlong_to_area(mid_lat, mid_lon)

    return Command(update={
        "person_1_postcode": p1,
        "person_2_postcode": p2,
        "midpoint_area": area["district"],  # or area["postcode"] / area dict
        "messages": [ToolMessage(content="Saved midpoint area", tool_call_id=runtime.tool_call_id)],
    })

@tool
def search_food(runtime: ToolRuntime) -> str:
    """Food agent finds the top 3 most suitable food spots in the desired location"""
    midpoint_area = runtime.state.get("midpoint_area")
    query = f"Find the top 3 suitable food spots within {midpoint_area}"
    response = food_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def search_activity(runtime: ToolRuntime) -> str:
    """Activity agent finds the top 3 most suitable food spots in the desired location"""
    midpoint_area = runtime.state.get("midpoint_area")
    query = f"Find the top 3 suitable activities within {midpoint_area}"
    response = activity_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(
        person_1_postcode: str,
        person_2_postcode: str,
        midpoint_area: str,
        food_place: str,
        activity_place: str,
        runtime: ToolRuntime
) -> Command:
    """Update the state when you know all of the values"""
    return Command(update={
        "person_1_postcode": person_1_postcode,
        "person_2_postcode": person_2_postcode,
        "midpoint_area": midpoint_area,
        "food_place": food_place,
        "activity_place": activity_place,
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)],
    })

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[find_area, search_food, search_activity, update_state],
    state_schema=MeetUpState,
    system_prompt="""
    You are a MeetUp coordinator. Delegate tasks to your specialists for a midpoint area, food spots and activities.
    First find the postcode information (like E1 1HJ) you need to update the state. Once that is done you can delegate the tasks.
    Once you have received their answers, coordinate the perfect meetup potentials for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I am Maieshah and my postcode is E6 6BT. My friend is Rahana and her postcode is E1 1NG. Can you help us find some good food spots and activities to do to meet up?")],
    }
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'activity_place': 'Queen Elizabeth Olympic Park, Stratford',
#  'food_place': 'Khana Khazana, 222A Green Street, Forest Gate, London E7 8LE',
#  'messages': [HumanMessage(content='I am Maieshah and my postcode is E6 6BT. My friend is Rahana and her postcode is E1 1NG. Can you help us find some good food spots and activities to do to meet up?', additional_kwargs={}, response_metadata={}, id='a8ab7e9b-b158-44f2-b343-239434d73ea6'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 427, 'prompt_tokens': 359, 'total_tokens': 786, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cq4KAXEmlUZEumeYVrXLOfS5EO4Bl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b4d23-3fee-77d1-91fd-1f4537aef065-0', tool_calls=[{'name': 'find_area', 'args': {'person_1_postcode': 'E6 6BT', 'person_2_postcode': 'E1 1NG'}, 'id': 'call_9xuENwyWZEdpRddRlaySKoNS', 'type': 'tool_call'}], usage_metadata={'input_tokens': 359, 'output_tokens': 427, 'total_tokens': 786, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#               ToolMessage(content='Saved midpoint area', name='find_area', id='0ca354e8-6c60-4be4-861c-5c0f7e20dfbd', tool_call_id='call_9xuENwyWZEdpRddRlaySKoNS'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 978, 'prompt_tokens': 410, 'total_tokens': 1388, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cq4KHpPxJBL4XTzRj8222PRybZzG2', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b4d23-5913-75f0-a30e-67afea2ca9d1-0', tool_calls=[{'name': 'find_area', 'args': {'person_1_postcode': 'E6 6BT', 'person_2_postcode': 'E1 1NG'}, 'id': 'call_GdSnSjLkwpbrveNHdGeaTxLP', 'type': 'tool_call'}, {'name': 'search_food', 'args': {}, 'id': 'call_iNtnqRcDsSC2e96fsd954ClS', 'type': 'tool_call'}, {'name': 'search_activity', 'args': {}, 'id': 'call_zN8H6ZcC0DWH9vGIINWwkvEJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 410, 'output_tokens': 978, 'total_tokens': 1388, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}}),
#               ToolMessage(content='Saved midpoint area', name='find_area', id='7cff9611-91b9-4e38-9277-e869599b19bd', tool_call_id='call_GdSnSjLkwpbrveNHdGeaTxLP'),
#               ToolMessage(content='Here are the top 3 halal-friendly spots in Newham that meet your criteria (Google rating over 4.3, suitable cuisines, and halal meat). Note on prayer spaces: on-site prayer spaces are not reported for these restaurants; you can use nearby mosques if needed.\n\n1) Khana Khazana\n- Location: 222A Green Street, Forest Gate, London E7 8LE (Newham)\n- Cuisine: Indian and Pakistani halal dishes\n- Halal: Yes\n- Google rating: Approximately 4.5\n- Muslim prayer space: No on-site prayer space reported\n- Why it’s a fit: Popular halal Indian/Pakistani option on Green Street with strong Google reviews\n\n2) Yaal Restaurant\n- Location: 404 Barking Road, East Ham, London E6 2SA (Newham)\n- Cuisine: Indian and Sri Lankan; halal options available\n- Halal: Yes\n- Google rating: Approximately 4.4\n- Muslim prayer space: No on-site prayer space reported\n- Why it’s a fit: Well-reviewed halal Indian/Sri Lankan menu in East Ham\n\n3) Hyderabad Darbar\n- Location: Green Street area (60-62 Green Street, London) near East Ham/Upton Park (Newham)\n- Cuisine: Hyderabadi Indian\n- Halal: Yes\n- Google rating: Approximately 4.4\n- Muslim prayer space: No on-site prayer space reported\n- Why it’s a fit: Noted for Hyderabadi flavors with solid halal credentials in the area\n\nIf you’d like, I can tailor picks further (e.g., closest to a specific tube station, vegetarian-friendly options, or places with explicit on-site prayer facilities).', name='search_food', id='3f6476eb-67c9-49d5-b33c-a6e99d77c133', tool_call_id='call_iNtnqRcDsSC2e96fsd954ClS'),
#               ToolMessage(content='Here are three top, beginner-friendly, affordable activities to do in Newham:\n\n1) Explore Queen Elizabeth Olympic Park (Stratford)\n- What it is: A massive, open park with riverside paths, green spaces, and iconic Olympic landmarks. Great for strolling, cycling, picnics, and views of the city.\n- Why it suits: Free to enter and use; lots of easy, low-cost ways to spend a day outdoors.\n- What to know (price/comfort): Access is free; some paid attractions nearby (if you want to upgrade).\n- Where: Stratford, Newham.\n- Source: Official QEOP site highlights free or budget-friendly things to do and “things to do under £10.”\n  - https://www.queenelizabetholympicpark.co.uk/explore-park/visitor-guides/things-do-under-10\n  - https://www.queenelizabetholympicpark.co.uk/homepage\n\n2) ArcelorMittal Orbit – Skyline views with the Orbit slide (in QEOP, Stratford)\n- What it is: The iconic red tower in the Olympic Park offering panoramic city views and, for thrill-seekers, the Orbit Slide.\n- Why it suits: Beginner-friendly (no special skills required); appeals to first-time visitors; a standout, memorable activity.\n- What to know (price/comfort): Tickets for the Orbit Skyline views with the slide are available (price around £16.75 per adult for the slide package, depending on options).\n- Where: Queen Elizabeth Olympic Park, Stratford.\n- Source: Headout listing for “Arcelormittal Orbit Skyline Views with the Slide” with example pricing.\n  - https://www.headout.com/arcelormittal-orbit-london-tickets/arcelormittal-orbit-skyline-views-with-the-slide-e-10758/\n\n3) The Crystal (Royal Docks, Newham)\n- What it is: A modern, interactive museum and education center focused on sustainable cities and future urban design.\n- Why it suits: Very beginner-friendly indoor exhibit; compact and easy to navigate; affordable admission.\n- What to know (price/comfort): Modest entry fee (roughly a few pounds, depending on time and promotions).\n- Where: Royal Docks, Newham.\n- Source: Timeout listing for The Crystal (price range and accessibility).\n  - https://timeout.com/london/things-to-do/the-crystal\n\nIf you’d like, I can tailor these options further (e.g., family-friendly, indoor vs. outdoors, or time of day) based on your plans.', name='search_activity', id='7e948105-4267-4e6a-a8a0-9b9ed90fd8c7', tool_call_id='call_zN8H6ZcC0DWH9vGIINWwkvEJ'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1303, 'prompt_tokens': 1468, 'total_tokens': 2771, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1216, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cq4ORhk9q96GmbhFZxwYyJxyRKcUx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b4d27-4856-7f60-b385-a745ec55e0b9-0', tool_calls=[{'name': 'update_state', 'args': {'person_1_postcode': 'E6 6BT', 'person_2_postcode': 'E1 1NG', 'midpoint_area': 'Newham - Stratford area', 'food_place': 'Khana Khazana, 222A Green Street, Forest Gate, London E7 8LE', 'activity_place': 'Queen Elizabeth Olympic Park, Stratford'}, 'id': 'call_b2WziAvbB4vYGkgYnUK0vcIf', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1468, 'output_tokens': 1303, 'total_tokens': 2771, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1216}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='727ddcb1-1a35-4011-a461-9ab17d89c7a5', tool_call_id='call_b2WziAvbB4vYGkgYnUK0vcIf'),
#               AIMessage(content='Great news, Maieshah! I’ve mapped out a meetup plan for you and Rahana in Newham, with a midpoint around Stratford. Here’s a quick summary and next steps.\n\nMidpoint area\n- Newham – Stratford area (close to both of you)\n\nTop halal-friendly food spots (near Newham)\n1) Khana Khazana\n   - Address: 222A Green Street, Forest Gate, London E7 8LE\n   - Cuisine: Indian and Pakistani halal dishes\n   - Halal: Yes\n   - Google rating: ~4.5\n   - Notes: Popular choice on Green Street; no on-site prayer space reported\n\n2) Yaal Restaurant\n   - Address: 404 Barking Road, East Ham, London E6 2SA\n   - Cuisine: Indian and Sri Lankan; halal options available\n   - Halal: Yes\n   - Google rating: ~4.4\n   - Notes: Well-reviewed halal Indian/Sri Lankan menu in East Ham\n\n3) Hyderabad Darbar\n   - Address: Green Street area (60-62 Green Street, London)\n   - Cuisine: Hyderabadi Indian\n   - Halal: Yes\n   - Google rating: ~4.4\n   - Notes: Noted for Hyderabadi flavors with halal credentials\n\nTop beginner-friendly, affordable activities in Newham\n1) Explore Queen Elizabeth Olympic Park (Stratford)\n   - Free to enter; great for strolling, cycling, picnics, views\n   - Location: Stratford, Newham\n\n2) ArcelorMittal Orbit – Skyline views with the Orbit slide\n   - Panoramic views; beginner-friendly\n   - Price: around £16.75 for the slide package (varies by option)\n   - Location: Queen Elizabeth Olympic Park, Stratford\n\n3) The Crystal (Royal Docks, Newham)\n   - Indoor, interactive museum focused on sustainable cities\n   - Affordable entry; easy to navigate\n   - Location: Royal Docks, Newham\n\nWhat I did\n- Calculated a midpoint area using your postcodes: E6 6BT (Maieshah) and E1 1NG (Rahana); result: Newham – Stratford area.\n- Picked halal-friendly food spots and beginner-friendly activities in that area.\n- Saved the state with all details updated.\n\nNext steps / options\n- Would you like me to:\n  - Check which spot is closest to a specific tube or bus stop (e.g., Stratford, East Ham, or Forest Gate)?\n  - Narrow down to a single restaurant and activity pair based on a time window (e.g., lunch + park stroll, or dinner + sunset view)?\n  - Look for places with on-site prayer spaces or quieter dining options?\n  - Add a rough schedule with time estimates (e.g., 1.5–2 hours for food + activity, transit times)?\n\nIf you share preferred times, I’ll tailor a precise plan and a simple, shareable itinerary.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 624, 'prompt_tokens': 1563, 'total_tokens': 2187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1280}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cq4OcnPVH33pjzizYykEY8EaiLe6M', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b4d27-7724-76d2-9c3c-6bce98281c2a-0', usage_metadata={'input_tokens': 1563, 'output_tokens': 624, 'total_tokens': 2187, 'input_token_details': {'audio': 0, 'cache_read': 1280}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  'midpoint_area': 'Newham - Stratford area',
#  'person_1_postcode': 'E6 6BT',
#  'person_2_postcode': 'E1 1NG'}

# %%
print(response["messages"][-1].content)
# Out:
# Great news, Maieshah! I’ve mapped out a meetup plan for you and Rahana in Newham, with a midpoint around Stratford. Here’s a quick summary and next steps.
#
# Midpoint area
# - Newham – Stratford area (close to both of you)
#
# Top halal-friendly food spots (near Newham)
# 1) Khana Khazana
#    - Address: 222A Green Street, Forest Gate, London E7 8LE
#    - Cuisine: Indian and Pakistani halal dishes
#    - Halal: Yes
#    - Google rating: ~4.5
#    - Notes: Popular choice on Green Street; no on-site prayer space reported
#
# 2) Yaal Restaurant
#    - Address: 404 Barking Road, East Ham, London E6 2SA
#    - Cuisine: Indian and Sri Lankan; halal options available
#    - Halal: Yes
#    - Google rating: ~4.4
#    - Notes: Well-reviewed halal Indian/Sri Lankan menu in East Ham
#
# 3) Hyderabad Darbar
#    - Address: Green Street area (60-62 Green Street, London)
#    - Cuisine: Hyderabadi Indian
#    - Halal: Yes
#    - Google rating: ~4.4
#    - Notes: Noted for Hyderabadi flavors with halal credentials
#
# Top beginner-friendly, affordable activities in Newham
# 1) Explore Queen Elizabeth Olympic Park (Stratford)
#    - Free to enter; great for strolling, cycling, picnics, views
#    - Location: Stratford, Newham
#
# 2) ArcelorMittal Orbit – Skyline views with the Orbit slide
#    - Panoramic views; beginner-friendly
#    - Price: around £16.75 for the slide package (varies by option)
#    - Location: Queen Elizabeth Olympic Park, Stratford
#
# 3) The Crystal (Royal Docks, Newham)
#    - Indoor, interactive museum focused on sustainable cities
#    - Affordable entry; easy to navigate
#    - Location: Royal Docks, Newham
#
# What I did
# - Calculated a midpoint area using your postcodes: E6 6BT (Maieshah) and E1 1NG (Rahana); result: Newham – Stratford area.
# - Picked halal-friendly food spots and beginner-friendly activities in that area.
# - Saved the state with all details updated.
#
# Next steps / options
# - Would you like me to:
#   - Check which spot is closest to a specific tube or bus stop (e.g., Stratford, East Ham, or Forest Gate)?
#   - Narrow down to a single restaurant and activity pair based on a time window (e.g., lunch + park stroll, or dinner + sunset view)?
#   - Look for places with on-site prayer spaces or quieter dining options?
#   - Add a rough schedule with time estimates (e.g., 1.5–2 hours for food + activity, transit times)?
#
# If you share preferred times, I’ll tailor a precise plan and a simple, shareable itinerary.

# %%
print(requests.get("https://api.postcodes.io/postcodes/E66BT").json())
print(requests.get("https://api.postcodes.io/postcodes/E11NG").json())
# Out:
# {'status': 200, 'result': {'postcode': 'E6 6BT', 'quality': 1, 'eastings': 543108, 'northings': 183082, 'country': 'England', 'nhs_ha': 'London', 'longitude': 0.061658, 'latitude': 51.528521, 'european_electoral_region': 'London', 'primary_care_trust': 'Newham', 'region': 'London', 'lsoa': 'Newham 024D', 'msoa': 'Newham 024', 'incode': '6BT', 'outcode': 'E6', 'parliamentary_constituency': 'East Ham', 'parliamentary_constituency_2024': 'East Ham', 'admin_district': 'Newham', 'parish': 'Newham, unparished area', 'admin_county': None, 'date_of_introduction': '199806', 'admin_ward': 'East Ham South', 'ced': None, 'ccg': 'NHS North East London', 'nuts': 'Newham', 'pfa': 'Metropolitan Police', 'nhs_region': 'London', 'ttwa': 'London', 'national_park': 'England (non-National Park)', 'bua': 'Newham', 'icb': 'NHS North East London Integrated Care Board', 'cancer_alliance': 'North East London', 'lsoa11': 'Newham 024D', 'msoa11': 'Newham 024', 'lsoa21': 'Newham 024D', 'msoa21': 'Newham 024', 'oa21': 'E00175038', 'ruc11': '(England/Wales) Urban major conurbation', 'ruc21': 'Urban: Nearer to a major town or city', 'lep1': 'London', 'lep2': None, 'codes': {'admin_district': 'E09000025', 'admin_county': 'E99999999', 'admin_ward': 'E05013910', 'parish': 'E43000215', 'parliamentary_constituency': 'E14001213', 'parliamentary_constituency_2024': 'E14001213', 'ccg': 'E38000255', 'ccg_id': 'A3A8R', 'ced': 'E99999999', 'nuts': 'TLI41', 'lsoa': 'E01003542', 'msoa': 'E02000737', 'lau2': 'E09000025', 'pfa': 'E23000001', 'nhs_region': 'E40000003', 'ttwa': 'E30000234', 'national_park': 'E65000001', 'bua': 'E63012003', 'icb': 'E54000029', 'cancer_alliance': 'E56000028', 'lsoa11': 'E01003542', 'msoa11': 'E02000737', 'lsoa21': 'E01003542', 'msoa21': 'E02000737', 'oa21': 'E00175038', 'ruc11': 'A1', 'ruc21': 'UN1', 'lep1': 'E37000051', 'lep2': None}}}
# {'status': 200, 'result': {'postcode': 'E1 1NG', 'quality': 1, 'eastings': 534346, 'northings': 181242, 'country': 'England', 'nhs_ha': 'London', 'longitude': -0.065275, 'latitude': 51.514138, 'european_electoral_region': 'London', 'primary_care_trust': 'Tower Hamlets', 'region': 'London', 'lsoa': 'Tower Hamlets 021C', 'msoa': 'Tower Hamlets 021', 'incode': '1NG', 'outcode': 'E1', 'parliamentary_constituency': 'Bethnal Green and Stepney', 'parliamentary_constituency_2024': 'Bethnal Green and Stepney', 'admin_district': 'Tower Hamlets', 'parish': 'Tower Hamlets, unparished area', 'admin_county': None, 'date_of_introduction': '198001', 'admin_ward': 'Whitechapel', 'ced': None, 'ccg': 'NHS North East London', 'nuts': 'Tower Hamlets', 'pfa': 'Metropolitan Police', 'nhs_region': 'London', 'ttwa': 'London', 'national_park': 'England (non-National Park)', 'bua': 'Tower Hamlets', 'icb': 'NHS North East London Integrated Care Board', 'cancer_alliance': 'North East London', 'lsoa11': 'Tower Hamlets 021C', 'msoa11': 'Tower Hamlets 021', 'lsoa21': 'Tower Hamlets 021C', 'msoa21': 'Tower Hamlets 021', 'oa21': 'E00183811', 'ruc11': '(England/Wales) Urban major conurbation', 'ruc21': 'Urban: Nearer to a major town or city', 'lep1': 'London', 'lep2': None, 'codes': {'admin_district': 'E09000030', 'admin_county': 'E99999999', 'admin_ward': 'E05009336', 'parish': 'E43000220', 'parliamentary_constituency': 'E14001086', 'parliamentary_constituency_2024': 'E14001086', 'ccg': 'E38000255', 'ccg_id': 'A3A8R', 'ced': 'E99999999', 'nuts': 'TLI42', 'lsoa': 'E01004321', 'msoa': 'E02000884', 'lau2': 'E09000030', 'pfa': 'E23000001', 'nhs_region': 'E40000003', 'ttwa': 'E30000234', 'national_park': 'E65000001', 'bua': 'E63012023', 'icb': 'E54000029', 'cancer_alliance': 'E56000028', 'lsoa11': 'E01004321', 'msoa11': 'E02000884', 'lsoa21': 'E01004321', 'msoa21': 'E02000884', 'oa21': 'E00183811', 'ruc11': 'A1', 'ruc21': 'UN1', 'lep1': 'E37000051', 'lep2': None}}}
